# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
plt.switch_backend('TKAgg')
sns.set_context('poster')
sns.set_style('darkgrid')
sns.set_palette(sns.color_palette('colorblind'))

# %%
df = pd.concat([pd.read_csv(i) for i in glob('results/*.csv')])
# This is going to include results from the mean depth maps - we can drop them
df = df[df['Year'] != 'Mean_Depth']
df['Year'].unique()
# Out:
# array([2018, 2017, 2016, 2015, 2012, 2013], dtype=object)

# %%
a = df.copy().groupby('Study Area').mean()
clpx_mean_thresh = a.loc['CLPX']['Inflection Threshold']
hv_mean_thresh = a.loc['Happy Valley']['Inflection Threshold']
# tuol_mean_thresh = a.loc['Tuolumne']['Inflection Threshold']
a.head()
# Out:
#               Drift Threshold (pct. of mean depth)    drift_area  \
# Study Area
# CLPX                                         140.0  2.258064e+07
# Happy Valley                                 140.0  5.627892e+06
#
#               drift_volume  mean_drift_depth  mean_not_drift_depth  \
# Study Area
# CLPX          1.737662e+07          0.913183              0.382368
# Happy Valley  4.771526e+06          1.043088              0.444769
#
#               not_drift_area  not_drift_volume  \
# Study Area
# CLPX            6.617247e+07      2.687120e+07
# Happy Valley    1.940042e+07      9.060594e+06
#
#               Drift Threshold (pct. of mean depth).1  Drift Area pct.  \
# Study Area
# CLPX                                           140.0        25.422149
# Happy Valley                                   140.0        22.486064
#
#               Not Drift Area pct.  Drift Volume pct.  Not Drift Volume pct.  \
# Study Area
# CLPX                    74.577851          39.352221              60.647727
# Happy Valley            77.513936          35.242301              64.757743
#
#               Drift Volume-Area Difference (pct.)  \
# Study Area
# CLPX                                    13.930072
# Happy Valley                            12.756237
#
#               Drift Volume-Area Difference Slope  Inflection Threshold  \
# Study Area
# CLPX                                   -0.985311            138.333333
# Happy Valley                           -0.572882            130.000000
#
#               Mean_Depth [m]  SD Depth [m]        CV
# Study Area
# CLPX                0.495022      0.280098  0.566492
# Happy Valley        0.547893      0.281638  0.526983

# %%
#a.to_csv('drift_defintion_results_mean_by_study_area.to_csv')

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Drift Threshold (pct. of mean depth)", y="Drift Volume-Area Difference (pct.)",
             hue="Study Area", data=mean_df)

plt.axvline(x=clpx_mean_thresh, alpha=0.4, c=sns.color_palette('colorblind')[0])
plt.axvline(x=hv_mean_thresh, alpha=0.4, c=sns.color_palette('colorblind')[1])
#plt.axvline(x=tuol_mean_thresh, alpha=0.4, c=sns.color_palette('colorblind')[2])

plt.suptitle('Drift Volume - Drift Area (%)')
plt.title('Vertical Lines are Mean Inflection Thresholds, Shaded Area is 95% Confidence Interval')

#plt.savefig('delta_curves_thresholds_study_area_hue.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-3c926c8254e4> in <module>
#       1 plt.figure(figsize=(16,10))
#       2 sns.lineplot(x="Drift Threshold (pct. of mean depth)", y="Drift Volume-Area Difference (pct.)",
# ----> 3              hue="Study Area", data=mean_df)
#       4
#       5 plt.axvline(x=clpx_mean_thresh, alpha=0.4, c=sns.color_palette('colorblind')[0])
#
# NameError: name 'mean_df' is not defined

# %%
sns.lmplot(x="CV", y="Inflection Threshold", hue='Study Area', data=df, height=16, aspect=1.5, truncate=True)

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Drift Threshold (pct. of mean depth)", y="Drift Volume-Area Difference (pct.)",
             hue="Study Area", style="Year", data=df)

# %%
#df2.set_index(['Study Area', 'Year'], inplace=True)

# %%
df2 = df.copy()
a = df2.groupby(['Study Area','Year'])
a['Drift Volume-Area Difference'].apply(lambda x: np.gradient(x).argmin())
# Out:
# Study Area    Year
# CLPX          2012    8
#               2013    5
#               2015    6
#               2016    6
#               2017    6
#               2018    6
# Happy Valley  2012    5
#               2013    5
#               2015    4
#               2016    4
#               2017    7
#               2018    8
# Name: Drift Volume-Area Difference, dtype: int64

# %%
pcts = np.arange(0.8,2.1,0.1) * 100
idx = a['Drift Volume-Area Difference'].apply(lambda x: np.gradient(x).argmin()).values

# %%
p = []
for i in idx:
    p.append(pcts[i])
np.mean(p)
# Out:
# 138.33333333333334

# %%
df3 = df.copy()
a = df2.groupby('Drift Threshold (% of mean depth)').mean()
a['gradient'] = np.gradient(a['Drift Volume-Area Difference'])
a.gradient
# Out:
# Drift Threshold (% of mean depth)
# 80.0     1.425128
# 90.0     1.002466
# 100.0    0.014717
# 110.0   -1.032833
# 120.0   -1.676681
# 130.0   -1.900184
# 140.0   -1.817389
# 150.0   -1.607581
# 160.0   -1.428148
# 170.0   -1.162198
# 180.0   -0.923513
# 190.0   -0.747239
# 200.0   -0.658239
# Name: gradient, dtype: float64

# %%
a.gradient.argmin()
# Out:
# /home/cparr/apps/miniconda3/envs/data-scratchbook/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   """Entry point for launching an IPython kernel.
# 129.99999999999997

# %%
clpx17 = pd.read_csv('drift_thresholds_CLPX_2017.csv')
clpx17.head()
# Out:
#   Unnamed: 0  drift_area  drift_volume  mean_drift_depth  \
# 0     0.43 m  60595359.0    40922684.0          0.675344
# 1     0.48 m  52597641.0    37282396.0          0.708823
# 2     0.53 m  44495913.0    33191504.0          0.745945
# 3     0.59 m  35256861.0    28021924.0          0.794793
# 4     0.64 m  28373307.0    23792008.0          0.838535
#
#    mean_not_drift_depth  not_drift_area  not_drift_volume  \
# 0              0.276251      33669474.0         9301241.0
# 1              0.310590      41667192.0        12941419.0
# 2              0.342229      49768920.0        17032366.0
# 3              0.376254      59007972.0        22201968.0
# 4              0.401142      65891526.0        26431854.0
#
#    Drift Threshold (% of mean depth)  Drift Area %  Not Drift Area %  \
# 0                               80.0     64.282041         35.717959
# 1                               90.0     55.797734         44.202266
# 2                              100.0     47.203089         52.796911
# 3                              110.0     37.401924         62.598076
# 4                              120.0     30.099567         69.900433
#
#    Drift Volume %  Not Drift Volume %  Drift Volume-Area Difference  Year  \
# 0       81.480375           18.519523                     17.198334  2017
# 1       74.232267           25.767412                     18.434533  2017
# 2       66.086970           33.912819                     18.883881  2017
# 3       55.793918           44.205915                     18.391994  2017
# 4       47.371813           52.627960                     17.272246  2017
#
#   Study Area
# 0       CLPX
# 1       CLPX
# 2       CLPX
# 3       CLPX
# 4       CLPX

# %%
plt.plot(np.gradient(clpx17['Drift Volume-Area Difference']))
