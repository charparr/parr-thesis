# %%
import rasterio
import matplotlib.pyplot as plt
from rasterio.plot import show
plt.switch_backend('tkagg')

# %%
src = rasterio.open('../DEMs/clpx/bare_earth/orthos/clpx_ortho_06_05_2017.tif')

# %%
ortho = src.read()

# %%
fig, ax = plt.subplots(figsize=(16,10))
show(src, ax=ax)

# %%
xtks = ax.xaxis.get_ticklabels()
xtks1 = [str(int(str(x)[-8:-2]) + 0) for x in xtks]

ytks = ax.yaxis.get_ticklabels()
ytks1 = [str(int(str(y)[-9:-2]) - 0 ) for y in ytks][::-1]

print("X TICKS...", xtks1)
print("Y TICKS...", ytks1)
# Out:
# X TICKS... ['400000', '402000', '404000', '406000', '408000', '410000', '412000', '414000', '416000']
# Y TICKS... ['7622000', '7620000', '7618000', '7616000', '7614000', '7612000', '7610000', '7608000']

# %%
fig2, ax2 = plt.subplots(figsize=(5,12))
im = show(ortho, ax = ax2)

im.set_xticklabels(xtks1)
im.set_yticklabels(ytks1)

ax2.set_title('June 5 2017 Orthomosaic')
ax2.set_ylabel('UTM E Zone 6 N')
ax2.set_xlabel('UTM N Zone 6 N')


plt.savefig('../DEMs/clpx/bare_earth/figs/clpx_06_05_2017_ortho.png', dpi=300, bbox_inches='tight')
