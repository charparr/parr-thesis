# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
import cv2
from rasterio.features import sieve
from rasterio.plot import show
cmap = plt.get_cmap('Spectral')

# %%
src = rasterio.open('../../anwr/camden/Apr14_2018_Camden_snow_depth_dDEM_2m_plus_057m.tif')

# %%
fig, ax = plt.subplots(figsize=(16, 10))
cmap.set_under('white')
show((src, 1), with_bounds=True, ax=ax, vmin=0, vmax=1, cmap=cmap)

plt.setp( ax.xaxis.get_majorticklabels(), rotation=45 )


#plt.setp( ax.xaxis.get_majorticklabels(), rotation=70 )

PCM=ax.get_children()[-2]
plt.colorbar(PCM, ax=ax)
plt.show()

# %%
arr = src.read(1)
arr[np.where(np.logical_and(arr > -9998, arr < 0))] = 0
#masked_arr = np.ma.masked_values(arr, src.nodata)
#masked_arr[masked_arr < 0] = 0
plt.imshow(arr, vmin=0, vmax=1)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 10))
cmap.set_under('white')
show(masked_arr, with_bounds=True, ax=ax, vmin=0, vmax=1, cmap=cmap)
PCM=ax.get_children()[-2]
plt.colorbar(PCM, ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 10))
cmap.set_under('white')
show((src, 1), with_bounds=True, ax=ax, vmin=0, vmax=1, cmap=cmap)
PCM=ax.get_children()[-2]
plt.colorbar(PCM, ax=ax)
plt.show()

# %%
src.write_mask(True)

# %%
fig, ax = plt.subplots(figsize=(16, 10))
cmap.set_under('white')
show(msk, with_bounds=True, ax=ax, vmin=0, vmax=1, cmap=cmap)
PCM=ax.get_children()[-2]
plt.colorbar(PCM, ax=ax)
plt.show()

# %%
arr = src.read(1)
import numpy.ma as ma
npmsk = ma.masked_equal(arr, -9999)

# %%
src.write_transform(npmsk)

# %%
plt.imshow(npmsk)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 10))
cmap.set_under(cmap(0.0))
show(npmsk, with_bounds=True, ax=ax, vmin=0, vmax=1.0, cmap=cmap)
PCM=ax.get_children()[-2]
plt.colorbar(PCM, ax=ax)
plt.show()

# %%
s = '../camden/Apr14_2018_Camden_snow_depth_dDEM_2m_plus_057m.tif'

# %%
s.split('.tif')[0]
